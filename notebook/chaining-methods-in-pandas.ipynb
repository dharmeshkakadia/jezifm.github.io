# %% [markdown]
# # Chaining Methods in Pandas

# %% [markdown]
# For data scientist who uses python in their workflow, there is a high probability he/she uses **pandas**. When using pandas it is normal to have a code that looks like this

# %%
import pandas as pd
import re

# %%
# Get dataset
csv_url = 'https://opendata.socrata.com/api/views/d2kg-fyem/rows.csv?accessType=DOWNLOAD'
data = pd.read_csv(csv_url)
data.head()
# Out:
#    FIPS code    Jurisdiction Division  Precincts  Total Registration  \
# 0  200000000    Alaska State      NaN        441              574441
# 1  200000000    Alaska State      NaN        441              574441
# 2  200000000    Alaska State      NaN        441              574441
# 3  100000000   Alabama State      NaN       2527             2986782
# 4  100100000  Autauga County      NaN         17               33806
#
#                           Make         Model                   Equipment Type  \
# 0                          NaN           NaN       Hand Counted Paper Ballots
# 1   Premier/Diebold (Dominion)  AccuVote TSX                  DRE-Touchscreen
# 2   Premier/Diebold (Dominion)   AccuVote OS                     Optical Scan
# 3                          NaN           NaN                              NaN
# 4  Election Systems & Software      AutoMARK  Ballot Marking Device or System
#
#   VVPAT Accessible Use Early Voting Absentee Ballots Polling Place State
# 0   NaN             No          Yes              Yes           Yes   NaN
# 1   Yes            Yes          Yes               No            No   NaN
# 2   NaN             No          Yes              Yes           Yes   NaN
# 3   NaN             No           No               No            No   NaN
# 4   NaN            Yes           No               No            No   NaN

# %% [markdown]
# Dataset contains the locations of electronic voting machines in the United States. Supposed we process the dataset.

# %%
def tidy_string(string):
    string = string.lower()
    string = re.sub('[^\w]+', '_', string)
    return string

processed_data = data.copy()
processed_data.columns = map(tidy_string, processed_data.columns)
processed_data = processed_data.reset_index()
processed_data['location'] = processed_data['jurisdiction'].str.split().str.get(0)
processed_data['state'] = processed_data['state'].fillna(processed_data['location'])
processed_data.head()
# Out:
#    index  fips_code    jurisdiction division  precincts  total_registration  \
# 0      0  200000000    Alaska State      NaN        441              574441
# 1      1  200000000    Alaska State      NaN        441              574441
# 2      2  200000000    Alaska State      NaN        441              574441
# 3      3  100000000   Alabama State      NaN       2527             2986782
# 4      4  100100000  Autauga County      NaN         17               33806
#
#                           make         model                   equipment_type  \
# 0                          NaN           NaN       Hand Counted Paper Ballots
# 1   Premier/Diebold (Dominion)  AccuVote TSX                  DRE-Touchscreen
# 2   Premier/Diebold (Dominion)   AccuVote OS                     Optical Scan
# 3                          NaN           NaN                              NaN
# 4  Election Systems & Software      AutoMARK  Ballot Marking Device or System
#
#   vvpat accessible_use early_voting absentee_ballots polling_place    state  \
# 0   NaN             No          Yes              Yes           Yes   Alaska
# 1   Yes            Yes          Yes               No            No   Alaska
# 2   NaN             No          Yes              Yes           Yes   Alaska
# 3   NaN             No           No               No            No  Alabama
# 4   NaN            Yes           No               No            No  Autauga
#
#   location
# 0   Alaska
# 1   Alaska
# 2   Alaska
# 3  Alabama
# 4  Autauga

# %% [markdown]
# We can improve this, by using pandas feature called `pipe` and `assign`

# %%
def fillna(df, missing, filled):
    df[missing] = df[missing].fillna(df[filled])
    return df

processed_data = (data
    .copy()
    .rename(columns=tidy_string)
    .reset_index()
    .assign(location=lambda x: x['jurisdiction'].str.split().str.get(0))
    .pipe(fillna, 'state', 'location')
)

processed_data.head()
# Out:
#    index  fips_code    jurisdiction division  precincts  total_registration  \
# 0      0  200000000    Alaska State      NaN        441              574441
# 1      1  200000000    Alaska State      NaN        441              574441
# 2      2  200000000    Alaska State      NaN        441              574441
# 3      3  100000000   Alabama State      NaN       2527             2986782
# 4      4  100100000  Autauga County      NaN         17               33806
#
#                           make         model                   equipment_type  \
# 0                          NaN           NaN       Hand Counted Paper Ballots
# 1   Premier/Diebold (Dominion)  AccuVote TSX                  DRE-Touchscreen
# 2   Premier/Diebold (Dominion)   AccuVote OS                     Optical Scan
# 3                          NaN           NaN                              NaN
# 4  Election Systems & Software      AutoMARK  Ballot Marking Device or System
#
#   vvpat accessible_use early_voting absentee_ballots polling_place    state  \
# 0   NaN             No          Yes              Yes           Yes   Alaska
# 1   Yes            Yes          Yes               No            No   Alaska
# 2   NaN             No          Yes              Yes           Yes   Alaska
# 3   NaN             No           No               No            No  Alabama
# 4   NaN            Yes           No               No            No  Autauga
#
#   location
# 0   Alaska
# 1   Alaska
# 2   Alaska
# 3  Alabama
# 4  Autauga
